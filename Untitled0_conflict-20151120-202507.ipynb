# %%
# %matplotlib inline
import db

# %%
a = db.L()

# %%
a.search('Onton')
# Out:
# |     ID | SHELF   | BOOK   | PAGE   | DESCRIPTION                    |
# |--------+---------+--------+--------+--------------------------------|
# | 100601 | main    | AlAs   | Fern   | Fern and Onton 1971: n 0.56-2. |

# %%
a.plot(100601)
