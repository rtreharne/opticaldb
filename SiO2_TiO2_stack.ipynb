# %%
# %matplotlib inline
import traml

# %%
a = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |

# %%
a.add(111704, 66)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111704 | 66               | passive   |

# %%
a.add(111407, 50)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111704 | 66               | passive   |
# |   2 |     111407 | 50               | passive   |

# %%
a.repeat('1,2',5)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111704 | 66               | passive   |
# |   2 |     111407 | 50               | passive   |
# |   3 |     111704 | 66               | passive   |
# |   4 |     111407 | 50               | passive   |
# |   5 |     111704 | 66               | passive   |
# |   6 |     111407 | 50               | passive   |
# |   7 |     111704 | 66               | passive   |
# |   8 |     111407 | 50               | passive   |
# |   9 |     111704 | 66               | passive   |
# |  10 |     111407 | 50               | passive   |
# |  11 |     111704 | 66               | passive   |
# |  12 |     111407 | 50               | passive   |

# %%
a.re
