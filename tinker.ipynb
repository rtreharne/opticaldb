# %%
# %matplotlib inline
import traml

# %%
a=traml.Stack()
a.remove()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     500403 | --               | substrate |
# |   1 |     116604 | 100              | passive   |

# %%
a.library.search('Treharne')
# Out:
# |     ID | SHELF   | BOOK          | PAGE         | DESCRIPTION                    |
# |--------+---------+---------------+--------------+--------------------------------|
# | 112003 | main    | ZnO           | Treharne-AZO | Treharne et al. 2011: n,k 0.3- |
# | 114203 | main    | CdS           | Treharne     | Treharne et al. 2011: n,k 0.3- |
# | 116605 | main    | CdTe          | Treharne     | Treharne et al. 2011: n,k 0.3- |
# | 316001 | glass   | NSG-OptiWhite | OptiWhite    | OptiWhite                      |

# %%
a.library.search('azo')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 112003 | main    | ZnO    | Treharne-AZO | Treharne et al. 2011: n,k 0.3- |

# %%
a.add(112003, d=750)
a.add(114203, d = 100)
a.add(116605, d=1000)

# %%
a.plot()

# %%
a.library.search('optiwhite')
# Out:
# |     ID | SHELF   | BOOK          | PAGE      | DESCRIPTION   |
# |--------+---------+---------------+-----------+---------------|
# | 316001 | glass   | NSG-OptiWhite | OptiWhite | OptiWhite     |

# %%
a.library.plot(316001)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-00943a620e97> in <module>()
# ----> 1 a.library.plot(316001)
#
# /home/treharne/Documents/python/pytraml/db.pyc in plot(self, key)
#     186
#     187     def plot(self, key):
# --> 188         data = self.data(key)
#     189         fig = plt.figure(figsize=(8,6))
#     190         ax = fig.add_subplot(111)
#
# /home/treharne/Documents/python/pytraml/db.pyc in data(self, key, flag)
#     148     def data(self, key, flag=True):
#     149         count = 0
# --> 150         page = self.page(key)
#     151         if flag:
#     152             for item in page['DATA']:
#
# /home/treharne/Documents/python/pytraml/db.pyc in page(self, key)
#     107                                 count_page += 1
#     108                                 if count_page == page_id:
# ...
