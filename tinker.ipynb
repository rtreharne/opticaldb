# %%
# %matplotlib inline
import traml

# %%
a = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     500403 | --               | substrate |
# |   1 |     116604 | 100              | passive   |

# %%
a.remove()

# %%
a.library.search('In2O3')
# Out:
# |     ID | SHELF   | BOOK       | PAGE      | DESCRIPTION                    |
# |--------+---------+------------+-----------+--------------------------------|
# | 400801 | other   | In2O3-SnO2 | Konig     | König et al. 2014: n,k 0.25-1. |
# | 400802 | other   | In2O3-SnO2 | Konig-EMA | König et al. 2014: EMA layer;  |

# %%
a.add(400801)

# %%
a.table()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     500403 | --               | substrate |
# |   1 |     400801 | 100              | passive   |

# %%
a.range
# Out:
# (0.31, 1.0)

# %%
a.library.search('Treharne')
# Out:
# |     ID | SHELF   | BOOK   | PAGE     | DESCRIPTION                    |
# |--------+---------+--------+----------+--------------------------------|
# | 116605 | main    | CdTe   | Treharne | Treharne et al. 2011: n,k 0.3- |

# %%
a.remove()
a.add(116605, d=2000)

# %%
a.plot()
