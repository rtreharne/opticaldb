# %%
# %matplotlib inline
import db

# %%
a = db.L()

# %%
a.search('cdte')
# Out:
# |     ID | SHELF   | BOOK   | PAGE        | DESCRIPTION                    |
# |--------+---------+--------+-------------+--------------------------------|
# | 116601 | main    | CdTe   | DeBell-300K | DeBell et al. 1979: n 6-22 µm; |
# | 116602 | main    | CdTe   | DeBell-80K  | DeBell et al. 1979: n 6-22 µm; |
# | 116603 | main    | CdTe   | DeBell-20K  | DeBell et al. 1979: n 6-22 µm; |

# %%
a.plot(116601)

# %%
a.search('perov')
# Out:
# |     ID | SHELF   | BOOK       | PAGE           | DESCRIPTION                    |
# |--------+---------+------------+----------------+--------------------------------|
# | 403401 | other   | CH3NH3PbI3 | Leguy          | Leguy et al. 2015; n,k 0.249-0 |
# | 403402 | other   | CH3NH3PbI3 | Leguy-hydrated | Leguy et al. 2015; Hydrated; n |

# %%
a.plot(403401)

# %%
a.page(403401)
# Out:
# {'COMMENTS': 'Single crystal CH<sub>3</sub>NH<sub>3</sub>PbI<sub>3</sub>; orientation unknown; room temperature; critical point model used for fit, 249 nm - 789 nm - fit not reliable for sub-bandgap region - see reference',
# ...
