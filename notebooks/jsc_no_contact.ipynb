# %%
# %matplotlib inline
import db
import traml

# %%
s = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |

# %%
s.library.search('ZnO')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 112001 | main    | ZnO    | Bond-o       | Bond et al. 1965: n(o) 0.45-4. |
# | 112002 | main    | ZnO    | Bond-e       | Bond et al. 1965: n(e) 0.45-4. |
# | 112003 | main    | ZnO    | Treharne-AZO | Treharne et al. 2011: n,k 0.3- |

# %%
s.add(112003, 1000)
s.add(112001, 100)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |

# %%
s.plot()

# %%
s.library.search('CdTe')
# Out:
# |     ID | SHELF   | BOOK   | PAGE        | DESCRIPTION                    |
# |--------+---------+--------+-------------+--------------------------------|
# | 116601 | main    | CdTe   | DeBell-300K | DeBell et al. 1979: n 6-22 µm; |
# | 116602 | main    | CdTe   | DeBell-80K  | DeBell et al. 1979: n 6-22 µm; |
# | 116603 | main    | CdTe   | DeBell-20K  | DeBell et al. 1979: n 6-22 µm; |
# | 116604 | main    | CdTe   | Marple      | Marple 1964: n 0.86-2.5 µm     |
# | 116605 | main    | CdTe   | Treharne    | Treharne et al. 2011: n,k 0.3- |

# %%
s.add(116605, 2000, film_type='absorber')
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |
# |   3 |     116605 | 2000             | absorber  |

# %%
s.plot()

# %%
s.jsc()
# Out:
# 20.2129138606 (ma/cm^2)
# 20.212913860645514

# %%
s.library.search('Au')
# Out:
# |     ID | SHELF   | BOOK   | PAGE        | DESCRIPTION                    |
# |--------+---------+--------+-------------+--------------------------------|
# | 100501 | main    | Ar     | Bideau-Mehu | Bideau-Mehu et al. 1981: n 0.1 |
# | 100701 | main    | GaAs   | Skauli      | Skauli et al. 2003: n 0.97-17  |
# | 101101 | main    | Au     | Rakic       | Rakić 1998: n,k 0.2066-12.40 µ |
# | 101102 | main    | Au     | Olmon-ev    | Olmon et al. 2012: Evaporated  |
# | 101103 | main    | Au     | Olmon-sc    | Olmon et al. 2012: Single-crys |
# | 101104 | main    | Au     | Olmon-ts    | Olmon et al. 2012: Template-st |
# | 101105 | main    | Au     | McPeak      | McPeak et al. 2015: Thin film; |
# | 101106 | main    | Au     | Babar       | Babar and Weaver 2015: n,k 0.2 |
# | 101107 | main    | Au     | Ordal       | Ordal et al. 1987: n,k 0.667-2 |
# | 101108 | main    | Au     | Windt       | Windt et al. 1988: n,k 0.0024- |
# ...

# %%
s.library.plot(101115)

# %%
s.add(101115, 10)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |
# |   3 |     116605 | 2000             | absorber  |
# |   4 |     101115 | 10               | passive   |

# %%
s.plot()

# %%
s.jsc()
# Out:
# 20.2798701169 (ma/cm^2)
# 20.279870116940355

# %%
s.library.search('CdS')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 114201 | main    | CdS    | Bieniewski-o | Bieniewski and Czyzak 1963: n( |
# | 114202 | main    | CdS    | Bieniewski-e | Bieniewski and Czyzak 1963: n( |
# | 114203 | main    | CdS    | Treharne     | Treharne et al. 2011: n,k 0.3- |
# | 115301 | main    | CdSe   | Lisitsa-o    | Lisitsa et al. 1969: n(o) 1.01 |
# | 115302 | main    | CdSe   | Lisitsa-e    | Lisitsa et al. 1969: n(e) 1.01 |

# %%
a.table()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a670ca64dc1a> in <module>()
# ----> 1 a.table()
#
# NameError: name 'a' is not defined

# %%
s.table()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |
# |   3 |     116605 | 2000             | absorber  |
# |   4 |     101115 | 10               | passive   |

# %%
s.add(114203, 150, loc=3)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |
# |   3 |     114203 | 150              | passive   |
# |   4 |     116605 | 2000             | absorber  |
# |   5 |     101115 | 10               | passive   |

# %%
s.d(3, 50)

# %%
s.jsc(E=1.45)
# Out:
# 19.4911671555 (ma/cm^2)
# 19.491167155494217

# %%
s.plot()

# %%
s.remove(4)
s.remove(4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-b4fa984c77ac> in <module>()
#       1 s.remove(4)
# ----> 2 s.remove(4)
#
# /home/treharne/Documents/python/pytraml/notebooks/traml.py in remove(self, loc)
#     424            self.config.pop()
#     425         elif len(self.config)>1:
# --> 426            del self.config[loc]
#     427
#     428         self.build()
#
# IndexError: list assignment index out of range

# %%
a.table()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a670ca64dc1a> in <module>()
# ----> 1 a.table()
#
# NameError: name 'a' is not defined

# %%
s.table()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     112001 | 100              | passive   |
# |   3 |     114203 | 50               | passive   |

# %%
a.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7744e8f272e6> in <module>()
# ----> 1 a.plot()
#
# NameError: name 'a' is not defined

# %%
s.plot()

# %%
s.library.search('SiO2')
# Out:
# |     ID | SHELF   | BOOK         | PAGE            | DESCRIPTION                    |
# |--------+---------+--------------+-----------------+--------------------------------|
# | 111401 | main    | SiO2         | Malitson        | Malitson 1965: Fused silica; n |
# | 111402 | main    | SiO2         | Ghosh-o         | Ghosh 1999: α-Quartz, n(o) 0.1 |
# | 111403 | main    | SiO2         | Ghosh-e         | Ghosh 1999: α-Quartz, n(e) 0.1 |
# | 111404 | main    | SiO2         | Radhakrishnan-o | Radhakrishnan 1951: α-Quartz;  |
# | 111405 | main    | SiO2         | Radhakrishnan-e | Radhakrishnan 1951: α-Quartz;  |
# | 111406 | main    | SiO2         | Kischkat        | Kischkat et al. 2012: Thin fil |
# | 111407 | main    | SiO2         | Gao             | Gao et al. 2013: Thin film; n, |
# | 111408 | main    | SiO2         | Lemarchand      | Lemarchand 2013: Thin film; n, |
# | 116001 | main    | Bi12SiO20    | Gospodinov      | Gospodinov et al. 1988: n 0.48 |
# ...

# %%
s.library.plot(111407)

# %%
s.add(111407)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111407 | 100              | passive   |

# %%
s.library.search('ZnO')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 112001 | main    | ZnO    | Bond-o       | Bond et al. 1965: n(o) 0.45-4. |
# | 112002 | main    | ZnO    | Bond-e       | Bond et al. 1965: n(e) 0.45-4. |
# | 112003 | main    | ZnO    | Treharne-AZO | Treharne et al. 2011: n,k 0.3- |

# %%
s.add(112003)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111407 | 100              | passive   |
# |   2 |     112003 | 100              | passive   |

# %%
s.plot()
