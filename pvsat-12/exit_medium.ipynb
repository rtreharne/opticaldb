# %%
# %matplotlib inline
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import traml

# %%
a = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |

# %%
a.library.search('CdS')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 114201 | main    | CdS    | Bieniewski-o | Bieniewski and Czyzak 1963: n( |
# | 114202 | main    | CdS    | Bieniewski-e | Bieniewski and Czyzak 1963: n( |
# | 114203 | main    | CdS    | Treharne     | Treharne et al. 2011: n,k 0.3- |
# | 115301 | main    | CdSe   | Lisitsa-o    | Lisitsa et al. 1969: n(o) 1.01 |
# | 115302 | main    | CdSe   | Lisitsa-e    | Lisitsa et al. 1969: n(e) 1.01 |

# %%
AZO = 112003
CdS = 114203

# %%
a.add(AZO, 1000)
a.add(CdS, 100)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     114203 | 100              | passive   |

# %%
a.plot()

# %%
print a.exit
# Out:
# None

# %%
CdTe = 116605

# %%
a.add(CdTe, film_type='absorber')
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     112003 | 1000             | passive   |
# |   2 |     114203 | 100              | passive   |
# |   3 |     116605 | 100              | absorber  |

# %%
a.plot(o='a')

# %%
a.jsc()
# Out:
# 21.5064033712 (ma/cm^2)
# 21.506403371198999
