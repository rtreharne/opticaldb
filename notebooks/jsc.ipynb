# %%
# %matplotlib inline
from scipy.optimize import minimize
import numpy as np
import traml

# %%
a = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |

# %%
a.library.search('ZnO')
# Out:
# |     ID | SHELF   | BOOK   | PAGE         | DESCRIPTION                    |
# |--------+---------+--------+--------------+--------------------------------|
# | 112001 | main    | ZnO    | Bond-o       | Bond et al. 1965: n(o) 0.45-4. |
# | 112002 | main    | ZnO    | Bond-e       | Bond et al. 1965: n(e) 0.45-4. |
# | 112003 | main    | ZnO    | Treharne-AZO | Treharne et al. 2011: n,k 0.3- |

# %%
a.library.plot(112003)

# %%
a.library.search('cdte')
# Out:
# |     ID | SHELF   | BOOK   | PAGE        | DESCRIPTION                    |
# |--------+---------+--------+-------------+--------------------------------|
# | 116601 | main    | CdTe   | DeBell-300K | DeBell et al. 1979: n 6-22 µm; |
# | 116602 | main    | CdTe   | DeBell-80K  | DeBell et al. 1979: n 6-22 µm; |
# | 116603 | main    | CdTe   | DeBell-20K  | DeBell et al. 1979: n 6-22 µm; |
# | 116604 | main    | CdTe   | Marple      | Marple 1964: n 0.86-2.5 µm     |
# | 116605 | main    | CdTe   | Treharne    | Treharne et al. 2011: n,k 0.3- |

# %%
a.library.plot(114203)

# %%
a.library.page(112003)
# Out:
# {'COMMENTS': 'An Al doped ZnO film (approx 2% wt. Al) was deposited on to a soda-lime glass substrate using RF magnetron sputtering. The resultant film had a resistivity of 4.7e10-4 Ohm.cm. A variable-angle ellipsometer was used to take amplitude and phase change measurements. The refractive index and extinction coefficient was extracted from a multi-oscillator model fit to the ellipsometry data, as a function of wavelength, from 300 to 900 nm',
# ...
