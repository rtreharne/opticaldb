# %%
# %matplotlib inline
import traml
import db

# %%
a = traml.Stack()
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |

# %%
a.add(111407, 98)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111407 | 98               | passive   |

# %%
a.add(112003, 52)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111407 | 98               | passive   |
# |   2 |     112003 | 52               | passive   |

# %%
a.repeat('1,2',20)
# Out:
# |   # |   Material | Thickness (nm)   | Type      |
# |-----+------------+------------------+-----------|
# |   0 |     301005 | --               | substrate |
# |   1 |     111407 | 98               | passive   |
# |   2 |     112003 | 52               | passive   |
# |   3 |     111407 | 98               | passive   |
# |   4 |     112003 | 52               | passive   |
# |   5 |     111407 | 98               | passive   |
# |   6 |     112003 | 52               | passive   |
# |   7 |     111407 | 98               | passive   |
# |   8 |     112003 | 52               | passive   |
# |   9 |     111407 | 98               | passive   |
# |  10 |     112003 | 52               | passive   |
# |  11 |     111407 | 98               | passive   |
# |  12 |     112003 | 52               | passive   |
# |  13 |     111407 | 98               | passive   |
# |  14 |     112003 | 52               | passive   |
# |  15 |     111407 | 98               | passive   |
# ...

# %%
a.plot()
