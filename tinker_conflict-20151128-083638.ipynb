# %%
# %matplotlib inline
import db
import traml

# %%
a = db.L()

# %%
a.search('Phillips')
# Out:
# |     ID | SHELF   | BOOK       | PAGE     | DESCRIPTION                    |
# |--------+---------+------------+----------+--------------------------------|
# | 403403 | other   | CH3NH3PbI3 | Phillips | Phillips et al. 2015; n,k 0.3- |

# %%
a.plot(403403)
# Out:
# 100
